# %% [markdown]
# Activity 3.1: Debugging Infinite Loops & Loop Logic Errors

# %%
# Fixed Snippet A: Infinite Loop
counter = 0

while counter < 5:
    print(counter)
    counter += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Fixed Snippet B: Incorrect Range
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Fixed Snippet C: Misplaced Break
for char in "hello":
    print(char)
    if char == 'l':
        print("Found 'l', stopping!")
        break
# Out:
# h
# e
# l
# Found 'l', stopping!
